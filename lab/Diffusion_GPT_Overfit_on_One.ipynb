# %%
# !pip install tensorflow-metal

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# WARNING: Ignoring invalid distribution ~ensorflow (/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages)
# Requirement already satisfied: tensorflow-metal in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: wheel~=0.35 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-metal) (0.47.0)
# Requirement already satisfied: six>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow-metal) (1.17.0)
# Requirement already satisfied: packaging>=24.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wheel~=0.35->tensorflow-metal) (26.2)
# WARNING: Ignoring invalid distribution ~ensorflow (/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages)

# %%
T = 200  # keep small for MNIST training speed

beta = tf.linspace(1e-4, 0.02, T)
alpha = 1.0 - beta
alpha_bar = tf.math.cumprod(alpha)

# %%
def extract(a, t, x_shape):
    batch_size = tf.shape(t)[0]
    out = tf.gather(a, t)
    return tf.reshape(out, [batch_size] + [1] * (len(x_shape) - 1))

# %%
def q_sample(x0, t, noise):
    sqrt_alpha_bar = tf.sqrt(extract(alpha_bar, t, tf.shape(x0)))
    sqrt_one_minus = tf.sqrt(1 - extract(alpha_bar, t, tf.shape(x0)))

    return sqrt_alpha_bar * x0 + sqrt_one_minus * noise

# %%
class TimeEmbedding(tf.keras.layers.Layer):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def call(self, t):
        half = self.dim // 2

        freqs = tf.exp(
            tf.linspace(0.0, -np.log(10000.0), half)
        )

        t = tf.cast(t, tf.float32)
        args = t[:, None] * freqs[None, :]

        return tf.concat([tf.sin(args), tf.cos(args)], axis=-1)

# %%
class ConvBlock(tf.keras.layers.Layer):
    def __init__(self, channels):
        super().__init__()

        self.conv1 = tf.keras.layers.Conv2D(channels, 3, padding="same")
        self.norm1 = tf.keras.layers.GroupNormalization(groups=8)
        self.act1 = tf.keras.layers.Activation("swish")

        self.conv2 = tf.keras.layers.Conv2D(channels, 3, padding="same")
        self.norm2 = tf.keras.layers.GroupNormalization(groups=8)
        self.act2 = tf.keras.layers.Activation("swish")

        self.film1 = FiLM(channels)
        self.film2 = FiLM(channels)

    def call(self, x, t_emb):
        x = self.conv1(x)
        x = self.norm1(x)
        x = self.act1(x)
        x = self.film1(x, t_emb)

        x = self.conv2(x)
        x = self.norm2(x)
        x = self.act2(x)
        x = self.film2(x, t_emb)

        return x

# %%
class FiLM(tf.keras.layers.Layer):
    def __init__(self, channels):
        super().__init__()
        self.to_gamma = tf.keras.layers.Dense(channels)
        self.to_beta = tf.keras.layers.Dense(channels)

    def call(self, x, t_emb):
        gamma = self.to_gamma(t_emb)
        beta = self.to_beta(t_emb)

        gamma = tf.reshape(gamma, [-1, 1, 1, tf.shape(x)[-1]])
        beta = tf.reshape(beta, [-1, 1, 1, tf.shape(x)[-1]])

        return x * (1.0 + gamma) + beta

# %%
class UNet(tf.keras.Model):
    def __init__(self, time_dim=128):
        super().__init__()

        self.time_embed = TimeEmbedding(time_dim)
        self.time_mlp = tf.keras.Sequential([
            tf.keras.layers.Dense(time_dim, activation="swish"),
            tf.keras.layers.Dense(time_dim),
        ])

        # encoder
        self.down1 = ConvBlock(32)
        self.down2 = ConvBlock(64)

        # bottleneck
        self.mid = ConvBlock(64)

        # decoder
        self.up1 = ConvBlock(64)
        self.up2 = ConvBlock(32)

        self.pool = tf.keras.layers.MaxPool2D(2)
        self.up = tf.keras.layers.UpSampling2D(2)

        self.final = tf.keras.layers.Conv2D(1, 1)

    def call(self, x, t):
        # time embedding
        t_emb = self.time_embed(t)
        t_emb = self.time_mlp(t_emb)

        # encoder
        x1 = self.down1(x, t_emb)
        x2 = self.down2(self.pool(x1), t_emb)

        # bottleneck
        mid = self.mid(self.pool(x2), t_emb)

        # decoder
        u2 = self.up(mid)
        u2 = tf.concat([u2, x2], axis=-1)
        u2 = self.up1(u2, t_emb)

        u1 = self.up(u2)
        u1 = tf.concat([u1, x1], axis=-1)
        u1 = self.up2(u1, t_emb)

        return self.final(u1)

# %%
optimizer = tf.keras.optimizers.Adam(1e-4)

@tf.function
def train_step(model, x0):
    batch_size = tf.shape(x0)[0]

    t = tf.random.uniform((batch_size,), 0, T, dtype=tf.int32)
    noise = tf.random.normal(tf.shape(x0))

    x_noisy = q_sample(x0, t, noise)

    with tf.GradientTape() as tape:
        noise_pred = model(x_noisy, t)
        loss = tf.reduce_mean((noise - noise_pred) ** 2)

    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

    return loss

# %%
(x_train, _), _ = tf.keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_train = x_train * 2.0 - 1.0  # scale to [-1, 1]
x_train = np.expand_dims(x_train, -1)

overfitting_data = []
for i in range(128):
    overfitting_data.append(x_train[0])
    
train_ds = tf.data.Dataset.from_tensor_slices(overfitting_data)
#train_ds = train_ds.shuffle(60000).batch(128)
train_ds = train_ds.batch(128)

# %%
model = UNet()
epochs = 250
for epoch in range(epochs):
    bar = tf.keras.utils.Progbar(len(train_ds)-1)

    for step, batch in enumerate(train_ds):
        loss = train_step(model, batch)
        bar.update(step, values=[("loss", loss)])

    print(f"Epoch {epoch}, Loss: {loss.numpy():.4f}")
# Out:
#       0/Unknown 13s 0s/step - loss: 3.9354
# Epoch 0, Loss: 3.9354
#       0/Unknown 2s 0s/step - loss: 3.0086
# Epoch 1, Loss: 3.0086
#       0/Unknown 3s 0s/step - loss: 2.2865
# Epoch 2, Loss: 2.2865
#       0/Unknown 1s 0s/step - loss: 1.9543
# Epoch 3, Loss: 1.9543
#       0/Unknown 2s 0s/step - loss: 1.7506
# Epoch 4, Loss: 1.7506
#       0/Unknown 2s 0s/step - loss: 1.5626
# Epoch 5, Loss: 1.5626
#       0/Unknown 1s 0s/step - loss: 1.5501
# Epoch 6, Loss: 1.5501
#       0/Unknown 1s 0s/step - loss: 1.4694
# Epoch 7, Loss: 1.4694
#       0/Unknown 2s 0s/step - loss: 1.4715
# Epoch 8, Loss: 1.4715
#       0/Unknown 2s 0s/step - loss: 1.3913
# Epoch 9, Loss: 1.3913
#       0/Unknown 1s 0s/step - loss: 1.4167
# Epoch 10, Loss: 1.4167
#       0/Unknown 1s 0s/step - loss: 1.3280
# Epoch 11, Loss: 1.3280
#       0/Unknown 3s 0s/step - loss: 1.3087
# Epoch 12, Loss: 1.3087
#       0/Unknown 2s 0s/step - loss: 1.2145
# Epoch 13, Loss: 1.2145
#       0/Unknown 1s 0s/step - loss: 1.2367
# Epoch 14, Loss: 1.2367
#       0/Unknown 2s 0s/step - loss: 1.1390
# Epoch 15, Loss: 1.1390
#       0/Unknown 3s 0s/step - loss: 1.1112
# Epoch 16, Loss: 1.1112
#       0/Unknown 1s 0s/step - loss: 1.1017
# Epoch 17, Loss: 1.1017
#       0/Unknown 3s 0s/step - loss: 1.0802
# Epoch 18, Loss: 1.0802
#       0/Unknown 3s 0s/step - loss: 1.0621
# Epoch 19, Loss: 1.0621
#       0/Unknown 1s 0s/step - loss: 1.0494
# Epoch 20, Loss: 1.0494
#       0/Unknown 1s 0s/step - loss: 1.0346
# Epoch 21, Loss: 1.0346
#       0/Unknown 2s 0s/step - loss: 1.0190
# Epoch 22, Loss: 1.0190
#       0/Unknown 3s 0s/step - loss: 1.0092
# Epoch 23, Loss: 1.0092
#       0/Unknown 1s 0s/step - loss: 1.0157
# Epoch 24, Loss: 1.0157
#       0/Unknown 1s 0s/step - loss: 0.9966
# Epoch 25, Loss: 0.9966
#       0/Unknown 2s 0s/step - loss: 0.9980
# Epoch 26, Loss: 0.9980
#       0/Unknown 3s 0s/step - loss: 1.0004
# Epoch 27, Loss: 1.0004
#       0/Unknown 1s 0s/step - loss: 0.9821
# Epoch 28, Loss: 0.9821
#       0/Unknown 1s 0s/step - loss: 0.9457
# Epoch 29, Loss: 0.9457
#       0/Unknown 2s 0s/step - loss: 0.9486
# Epoch 30, Loss: 0.9486
#       0/Unknown 2s 0s/step - loss: 0.9233
# Epoch 31, Loss: 0.9233
#       0/Unknown 1s 0s/step - loss: 0.9319
# Epoch 32, Loss: 0.9319
#       0/Unknown 1s 0s/step - loss: 0.9058
# Epoch 33, Loss: 0.9058
#       0/Unknown 2s 0s/step - loss: 0.9322
# Epoch 34, Loss: 0.9322
#       0/Unknown 3s 0s/step - loss: 0.8970
# Epoch 35, Loss: 0.8970
#       0/Unknown 1s 0s/step - loss: 0.8991
# Epoch 36, Loss: 0.8991
#       0/Unknown 1s 0s/step - loss: 0.9003
# Epoch 37, Loss: 0.9003
#       0/Unknown 3s 0s/step - loss: 0.8814
# Epoch 38, Loss: 0.8814
#       0/Unknown 2s 0s/step - loss: 0.8931
# Epoch 39, Loss: 0.8931
#       0/Unknown 1s 0s/step - loss: 0.8677
# Epoch 40, Loss: 0.8677
#       0/Unknown 2s 0s/step - loss: 0.8328
# Epoch 41, Loss: 0.8328
#       0/Unknown 3s 0s/step - loss: 0.8546
# Epoch 42, Loss: 0.8546
#       0/Unknown 1s 0s/step - loss: 0.8431
# Epoch 43, Loss: 0.8431
#       0/Unknown 1s 0s/step - loss: 0.8005
# Epoch 44, Loss: 0.8005
#       0/Unknown 2s 0s/step - loss: 0.8036
# Epoch 45, Loss: 0.8036
#       0/Unknown 3s 0s/step - loss: 0.7802
# Epoch 46, Loss: 0.7802
#       0/Unknown 1s 0s/step - loss: 0.7937
# Epoch 47, Loss: 0.7937
#       0/Unknown 1s 0s/step - loss: 0.3641
# Epoch 114, Loss: 0.3641
#       0/Unknown 3s 0s/step - loss: 0.3722
# Epoch 115, Loss: 0.3722
#       0/Unknown 2s 0s/step - loss: 0.3631
# Epoch 116, Loss: 0.3631
#       0/Unknown 1s 0s/step - loss: 0.3692
# Epoch 117, Loss: 0.3692
#       0/Unknown 1s 0s/step - loss: 0.3727
# Epoch 118, Loss: 0.3727
#       0/Unknown 3s 0s/step - loss: 0.3755
# Epoch 119, Loss: 0.3755
#       0/Unknown 2s 0s/step - loss: 0.3547
# Epoch 120, Loss: 0.3547
#       0/Unknown 1s 0s/step - loss: 0.3546
# Epoch 121, Loss: 0.3546
#       0/Unknown 1s 0s/step - loss: 0.3716
# Epoch 122, Loss: 0.3716
#       0/Unknown 2s 0s/step - loss: 0.3449
# Epoch 123, Loss: 0.3449
#       0/Unknown 2s 0s/step - loss: 0.3321
# Epoch 124, Loss: 0.3321
#       0/Unknown 1s 0s/step - loss: 0.3201
# Epoch 125, Loss: 0.3201
#       0/Unknown 1s 0s/step - loss: 0.3362
# Epoch 126, Loss: 0.3362
#       0/Unknown 3s 0s/step - loss: 0.3409
# Epoch 127, Loss: 0.3409
#       0/Unknown 2s 0s/step - loss: 0.3684
# Epoch 128, Loss: 0.3684
#       0/Unknown 2s 0s/step - loss: 0.3321
# Epoch 129, Loss: 0.3321
#       0/Unknown 3s 0s/step - loss: 0.3615
# Epoch 130, Loss: 0.3615
#       0/Unknown 1s 0s/step - loss: 0.3311
# Epoch 131, Loss: 0.3311
#       0/Unknown 1s 0s/step - loss: 0.3503
# Epoch 132, Loss: 0.3503
#       0/Unknown 3s 0s/step - loss: 0.3405
# Epoch 133, Loss: 0.3405
#       0/Unknown 2s 0s/step - loss: 0.3440
# Epoch 134, Loss: 0.3440
#       0/Unknown 1s 0s/step - loss: 0.3310
# Epoch 135, Loss: 0.3310
#       0/Unknown 1s 0s/step - loss: 0.3492
# Epoch 136, Loss: 0.3492
#       0/Unknown 3s 0s/step - loss: 0.3190
# Epoch 137, Loss: 0.3190
#       0/Unknown 2s 0s/step - loss: 0.3198
# Epoch 138, Loss: 0.3198
#       0/Unknown 1s 0s/step - loss: 0.3283
# Epoch 139, Loss: 0.3283
#       0/Unknown 3s 0s/step - loss: 0.3537
# Epoch 140, Loss: 0.3537
#       0/Unknown 2s 0s/step - loss: 0.3224
# Epoch 141, Loss: 0.3224
#       0/Unknown 3s 0s/step - loss: 0.3038
# Epoch 142, Loss: 0.3038
#       0/Unknown 3s 0s/step - loss: 0.3219
# Epoch 143, Loss: 0.3219
#       0/Unknown 1s 0s/step - loss: 0.3092
# Epoch 144, Loss: 0.3092
#       0/Unknown 1s 0s/step - loss: 0.3227
# Epoch 145, Loss: 0.3227
#       0/Unknown 2s 0s/step - loss: 0.3070
# Epoch 146, Loss: 0.3070
#       0/Unknown 2s 0s/step - loss: 0.3113
# Epoch 147, Loss: 0.3113
#       0/Unknown 1s 0s/step - loss: 0.2929
# Epoch 148, Loss: 0.2929
#       0/Unknown 2s 0s/step - loss: 0.2946
# Epoch 149, Loss: 0.2946
#       0/Unknown 2s 0s/step - loss: 0.2980
# Epoch 150, Loss: 0.2980
#       0/Unknown 2s 0s/step - loss: 0.3066
# Epoch 151, Loss: 0.3066
#       0/Unknown 2s 0s/step - loss: 0.2949
# Epoch 152, Loss: 0.2949
#       0/Unknown 2s 0s/step - loss: 0.2975
# Epoch 153, Loss: 0.2975
#       0/Unknown 1s 0s/step - loss: 0.3211
# Epoch 154, Loss: 0.3211
#       0/Unknown 1s 0s/step - loss: 0.3222
# Epoch 155, Loss: 0.3222
#       0/Unknown 2s 0s/step - loss: 0.2771
# Epoch 156, Loss: 0.2771
#       0/Unknown 3s 0s/step - loss: 0.2970
# Epoch 157, Loss: 0.2970
#       0/Unknown 1s 0s/step - loss: 0.2898
# Epoch 158, Loss: 0.2898
#       0/Unknown 1s 0s/step - loss: 0.3176
# Epoch 159, Loss: 0.3176
#       0/Unknown 2s 0s/step - loss: 0.2897
# Epoch 160, Loss: 0.2897
#       0/Unknown 3s 0s/step - loss: 0.2763
# Epoch 161, Loss: 0.2763
#       0/Unknown 1s 0s/step - loss: 0.2910
# Epoch 162, Loss: 0.2910
#       0/Unknown 3s 0s/step - loss: 0.2737
# Epoch 163, Loss: 0.2737
#       0/Unknown 2s 0s/step - loss: 0.2870
# Epoch 164, Loss: 0.2870
#       0/Unknown 1s 0s/step - loss: 0.2739
# Epoch 165, Loss: 0.2739
#       0/Unknown 3s 0s/step - loss: 0.2906
# Epoch 166, Loss: 0.2906
#       0/Unknown 3s 0s/step - loss: 0.2822
# Epoch 167, Loss: 0.2822
#       0/Unknown 1s 0s/step - loss: 0.2864
# Epoch 168, Loss: 0.2864
#       0/Unknown 3s 0s/step - loss: 0.2608
# Epoch 169, Loss: 0.2608
#       0/Unknown 2s 0s/step - loss: 0.2685
# Epoch 170, Loss: 0.2685
#       0/Unknown 3s 0s/step - loss: 0.2771
# Epoch 171, Loss: 0.2771
#       0/Unknown 3s 0s/step - loss: 0.2899
# Epoch 172, Loss: 0.2899
#       0/Unknown 3s 0s/step - loss: 0.3066
# Epoch 173, Loss: 0.3066
#       0/Unknown 2s 0s/step - loss: 0.2624
# Epoch 174, Loss: 0.2624
#       0/Unknown 2s 0s/step - loss: 0.3029
# Epoch 175, Loss: 0.3029
#       0/Unknown 3s 0s/step - loss: 0.2804
# Epoch 176, Loss: 0.2804
#       0/Unknown 3s 0s/step - loss: 0.2770
# Epoch 177, Loss: 0.2770
#       0/Unknown 3s 0s/step - loss: 0.2738
# Epoch 178, Loss: 0.2738
#       0/Unknown 3s 0s/step - loss: 0.2818
# Epoch 179, Loss: 0.2818
#       0/Unknown 1s 0s/step - loss: 0.2760
# Epoch 180, Loss: 0.2760
#       0/Unknown 2s 0s/step - loss: 0.2728
# Epoch 181, Loss: 0.2728
#       0/Unknown 2s 0s/step - loss: 0.2469
# Epoch 182, Loss: 0.2469
#       0/Unknown 1s 0s/step - loss: 0.2897
# Epoch 183, Loss: 0.2897
#       0/Unknown 1s 0s/step - loss: 0.2889
# Epoch 184, Loss: 0.2889
#       0/Unknown 2s 0s/step - loss: 0.2823
# Epoch 185, Loss: 0.2823
#       0/Unknown 3s 0s/step - loss: 0.2801
# Epoch 186, Loss: 0.2801
#       0/Unknown 1s 0s/step - loss: 0.2643
# Epoch 187, Loss: 0.2643
#       0/Unknown 1s 0s/step - loss: 0.2414
# Epoch 188, Loss: 0.2414
#       0/Unknown 2s 0s/step - loss: 0.2717
# Epoch 189, Loss: 0.2717
#       0/Unknown 2s 0s/step - loss: 0.2757
# Epoch 190, Loss: 0.2757
#       0/Unknown 1s 0s/step - loss: 0.2722
# Epoch 191, Loss: 0.2722
#       0/Unknown 1s 0s/step - loss: 0.2377
# Epoch 192, Loss: 0.2377
#       0/Unknown 3s 0s/step - loss: 0.2475
# Epoch 193, Loss: 0.2475
#       0/Unknown 2s 0s/step - loss: 0.2499
# Epoch 194, Loss: 0.2499
#       0/Unknown 2s 0s/step - loss: 0.2565
# Epoch 195, Loss: 0.2565
#       0/Unknown 2s 0s/step - loss: 0.2429
# Epoch 196, Loss: 0.2429
#       0/Unknown 2s 0s/step - loss: 0.2785
# Epoch 197, Loss: 0.2785
#       0/Unknown 2s 0s/step - loss: 0.2704
# Epoch 198, Loss: 0.2704
#       0/Unknown 3s 0s/step - loss: 0.2501
# Epoch 199, Loss: 0.2501
#       0/Unknown 1s 0s/step - loss: 0.2443
# Epoch 200, Loss: 0.2443
#       0/Unknown 1s 0s/step - loss: 0.2438
# Epoch 201, Loss: 0.2438
#       0/Unknown 2s 0s/step - loss: 0.2551
# Epoch 202, Loss: 0.2551
#       0/Unknown 2s 0s/step - loss: 0.2424
# Epoch 203, Loss: 0.2424
#       0/Unknown 1s 0s/step - loss: 0.2336
# Epoch 204, Loss: 0.2336
#       0/Unknown 1s 0s/step - loss: 0.2452
# Epoch 205, Loss: 0.2452
#       0/Unknown 2s 0s/step - loss: 0.2385
# Epoch 206, Loss: 0.2385
#       0/Unknown 3s 0s/step - loss: 0.2606
# Epoch 207, Loss: 0.2606
#       0/Unknown 3s 0s/step - loss: 0.2528
# Epoch 208, Loss: 0.2528
#       0/Unknown 3s 0s/step - loss: 0.2473
# Epoch 209, Loss: 0.2473
#       0/Unknown 2s 0s/step - loss: 0.2468
# Epoch 210, Loss: 0.2468
#       0/Unknown 3s 0s/step - loss: 0.2376
# Epoch 211, Loss: 0.2376
#       0/Unknown 2s 0s/step - loss: 0.2606
# Epoch 212, Loss: 0.2606
#       0/Unknown 1s 0s/step - loss: 0.2774
# Epoch 213, Loss: 0.2774
#       0/Unknown 2s 0s/step - loss: 0.2553
# Epoch 214, Loss: 0.2553
#       0/Unknown 2s 0s/step - loss: 0.2620
# Epoch 215, Loss: 0.2620
#       0/Unknown 1s 0s/step - loss: 0.2284
# Epoch 216, Loss: 0.2284
#       0/Unknown 1s 0s/step - loss: 0.2378
# Epoch 217, Loss: 0.2378
#       0/Unknown 4s 0s/step - loss: 0.2356
# Epoch 218, Loss: 0.2356
#       0/Unknown 4s 0s/step - loss: 0.2621
# Epoch 219, Loss: 0.2621
#       0/Unknown 3s 0s/step - loss: 0.2279
# Epoch 220, Loss: 0.2279
#       0/Unknown 1s 0s/step - loss: 0.2371
# Epoch 221, Loss: 0.2371

# %%
def sample(model, n=16):
    x = tf.random.normal((n, 28, 28, 1))

    for t in reversed(range(T)):
        t_batch = tf.fill([n], t)

        noise_pred = model(x, t_batch)

        beta_t = beta[t]
        alpha_t = alpha[t]
        alpha_bar_t = alpha_bar[t]

        x = (1 / tf.sqrt(alpha_t)) * (
            x - (beta_t / tf.sqrt(1 - alpha_bar_t)) * noise_pred
        )

        if t > 0:
            x += tf.sqrt(beta_t) * tf.random.normal(tf.shape(x))

    return x

# %%
def sample_step(model, x, t):
    t_batch = tf.fill([1], t)

    noise_pred = model(x, t_batch)

    beta_t = beta[t]
    alpha_t = alpha[t]
    alpha_bar_t = alpha_bar[t]

    x = (1 / tf.sqrt(alpha_t)) * (
        x - (beta_t / tf.sqrt(1 - alpha_bar_t)) * noise_pred
    )

    if t > 0:
        x += tf.sqrt(beta_t) * tf.random.normal(tf.shape(x))

    return x

# %%
imgs = sample(model, 16)

imgs = (imgs + 1) / 2.0  # back to [0,1]

plt.figure(figsize=(4,4))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.imshow(tf.squeeze(imgs[i]), cmap="gray")
    plt.axis("off")

plt.show()

# %%
# Save a GIF using logged images
def save_gif(img_list, path="", interval=200):
    # Transform images from [-1,1] to [0, 255]
    imgs = []
    for im in img_list:
        im = np.array(im)
        im = (im + 1) / 2.0
        im = np.clip(im, 0, 255).astype(np.int32)
        im = Image.fromarray(im)
        imgs.append(im)
    
    imgs = iter(imgs)

    # Extract first image from iterator
    img = next(imgs)

    # Append the other images and save as GIF
    img.save(fp=path, format='GIF', append_images=imgs,
             save_all=True, duration=interval, loop=0)

# %%
x = tf.random.normal((1,28,28,1))
img_list = []
img_list.append(tf.squeeze((x+1)*127.5))

for t in reversed(range(T)):
    x = sample_step(model, x, t)
    img_list.append(tf.squeeze((x+1)*127.5))

    if t % 25==0:
        plt.imshow(tf.squeeze((x+1)*127.5), cmap="gray")
        plt.show()

save_gif(img_list + ([img_list[-1]] * 100), f"ddpm_gpt_{epochs}.gif", interval=20)

plt.imshow(np.array(np.clip((x[0] + 1) * 127.5, 0, 255), np.uint8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 13
#      10         plt.imshow(tf.squeeze((x+1)*127.5), cmap="gray")
#      11         plt.show()
# ---> 13 save_gif(img_list + ([img_list[-1]] * 100), f"ddpm_gpt_{epochs}.gif", interval=20)
#      15 plt.imshow(np.array(np.clip((x[0] + 1) * 127.5, 0, 255), np.uint8))
#      16 plt.show()
#
# NameError: name 'save_gif' is not defined

# %%
T
# Out:
# 200
